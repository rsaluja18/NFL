# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train = pd.read_excel('Draft Cornerbacks Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('Draft Cornerbacks Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#    Average INTs  Average PDs  Average Tackles  Height  Weight  Arm Length  \
# 0      2.666667          0.0        46.666667      73     190       31.00
# 1      1.500000          8.5        41.750000      71     192       32.25
# 2      2.500000          6.5        40.500000      72     197       32.25
# 3      4.000000          9.0        41.000000      72     193       31.25
# 4      2.000000         15.0        30.000000      71     183       31.25
#
#    40 Time  3-Cone Time  20 Yard Shuttle Time  Verticle Jump  Broad Jump  \
# 0     4.38         6.61                  3.94           36.0         123
# 1     4.47         6.90                  4.32           32.0         117
# 2     4.41         6.75                428.00            0.0         125
# 3     4.36         0.00                  4.12           38.5           0
# 4     4.32         0.00                  0.00           39.0         136
#
#    Result
# 0      99
# 1      97
# 2      95
# 3      94
# 4      96

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result"]
features = ["Average INTs", "Average PDs", "Average Tackles", "Height", "Weight", "Arm Length", "40 Time", "3-Cone Time", "20 Yard Shuttle Time", "Verticle Jump", "Broad Jump"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [96 94 95 99 94 94]

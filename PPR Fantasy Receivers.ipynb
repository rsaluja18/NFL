# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('PPR Fantasy WR Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 PPR Fantasy WR Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#     GP   TGT   REC   YDS   YDS/G   AVG   TD   ATT   YDS.1   AVG.1   TD.1   FL  \
# 0   16   163   115  1572    98.3  13.7   11     1      -7    -7.0      0    2
# 1   15   169   111  1386    92.4  12.5   13     0       0     0.0      0    0
# 2   16   137    87  1479    92.4  17.0   12    22     151     6.9      1    0
# 3   16   170   113  1677   104.8  14.8    8     2      12     6.0      0    2
# 4   16   147   125  1405    87.8  11.2    9     0       0     0.0      0    2
#
#     FPTS   FPPG  Result (PPG)
# 0    334   20.9            18
# 1    329   21.9            18
# 2    327   20.4            16
# 3    325   20.3            18
# 4    315   19.7            23

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (PPG)"]
features = [" GP", " TGT", " REC", " YDS", " YDS/G", " AVG", " TD", " FPTS", " FPPG"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [18 13 18 14 13 13 16 16 16 16 16 16 16 16 16 16 16 12 15 12 16 15 16 16
#  11 15 16 16 15 15 10 16 11 15  8  7 11 16 10 17 20 11 13  8 14 10 15 11
#  10 15 10 13 15  8 10 15 15 10  9 13 13 15  9  9 13 13  9  6  9  9  9  8
#   8  9  8  8  8  8  8  8  8  8  9  9  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8]

# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('PPR Fantasy TE Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 PPR Fantasy TE Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#     GP   TGT   REC   YDS   YDS/G   AVG   TD   FL   FPTS   FPPG  Result (PPG)
# 0   16   150   103  1336    83.5  13.0   10    1    294   18.4            16
# 1   16   156   116  1163    72.7  10.0    8    0    280   17.5            14
# 2   16   136    88  1377    86.1  15.7    5    0    258   16.1            16
# 3   16   110    66   750    46.9  11.4   13    1    223   13.9             8
# 4   16   101    68   896    56.0  13.2    6    0    193   12.1            12

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (PPG)"]
features = [" GP", " TGT", " REC", " YDS", " YDS/G", " AVG", " TD", " FPTS", " FPPG"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [14 14 12  8 12 14 14  6  6  6 14  4  4  6  7  2  4  2  9 14  9  2  2  6
#  14  4  6  4  4  4 14  6  4  2  2  2  3  2  2  2  2  2  2  6  2  6  6  2
#   2  2  6  2  6  6  6  2 11  6  2]

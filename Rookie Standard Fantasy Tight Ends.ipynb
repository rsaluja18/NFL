# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('Standard Fantasy TE Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 Rookie Fantasy TE Testing Data.xlsx', encoding = "iso-8859-1")
test.head()
# Out:
#     GP   TGT   REC   YDS      YDS/G        AVG   TD   FL   FPTS   FPPG  \
# 0   10     0    43   515  51.500000  11.976744    6    0      0      0
# 1   12     0    44   641  53.416667  14.568182    4    0      0      0
# 2   10     0    21   240  24.000000  11.428571    5    0      0      0
# 3   11     0    70   916  83.272727  13.085714   14    0      0      0
# 4   13     0    65  1004  77.230769  15.446154    7    0      0      0
#
#    Result (PPG)      Unnamed: 11
# 0           NaN        cole kmet
# 1           NaN     devin asiasi
# 2           NaN     dalton keene
# 3           NaN    adam trautman
# 4           NaN  harrison bryant

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (PPG)"]
features = [" GP", " REC", " YDS", " YDS/G", " AVG", " TD"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [4 8 3 9 9]

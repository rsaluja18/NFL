# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('Standard Fantasy RB Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 Standard Fantasy RB Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#     GP   ATT   YDS   AVG   TD   TGT   REC   YDS.1   YDS/G   AVG.1   TD.1   FL  \
# 0   14   256  1251   4.9   17    81    59     580    41.4     9.8      4    1
# 1   16   261  1307   5.0   11   121    91     721    45.1     7.9      4    0
# 2   16   219  1098   5.0    7   124   107     867    54.2     8.1      6    1
# 3   15   194   883   4.6   14   105    81     709    47.3     8.8      4    0
# 4   15   304  1434   4.7    6    95    77     567    37.8     7.4      3    1
#
#     FPTS   FPPG  Result (PPG)
# 0    313   22.4            13
# 1    294   18.4            15
# 2    279   17.4            22
# 3    272   18.1            12
# 4    251   16.7            16

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (PPG)"]
features = [" GP", " ATT", " YDS", " AVG", " TD", " TGT", " REC", " YDS.1", " YDS/G", " AVG.1", " TD.1", " FL", " FPTS", " FPPG"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [15 13 11 13 11  9 12 14  5 10 14  8 12  8  7 14 12  8  9  3 12  7  5  3
#   9  9 12  3  5  5 12 14 14  5  9 12  4  3  3  7  7  3  7 14  5  3  5  5
#   7  3  5 14  9  9  5  5 14  3 14  5  5 14 14  1  3  9  5  5 14  3  5 14
#  14  7 14  9 14  9  5  5 14  7  9  1  3  5  5 14  5 14  5 14 14  5 14 14
#   5 14 14 14]

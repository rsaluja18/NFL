# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('Fantasy Quarterbacks Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 Fantasy Rookie QB Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#     GP   ATT   CMP   YDS   YDS/G   TD   INT   RATE   ATT.1   YDS.1   AVG  \
# 0   16   580   383  5097   318.6   50    12  113.8      60     272   4.5
# 1   16   608   422  4924   307.8   35     7  108.1      33     125   3.8
# 2   16   675   452  5129   320.6   34    16   96.5      31      98   3.2
# 3   16   639   430  4593   287.1   39    15   98.7      46     148   3.2
# 4   16   505   345  4165   260.3   26     9  103.1      99     551   5.6
#
#     TD.1   FL   FPTS   FPPG  Result (PPG)
# 0      2    2    516   32.3            25
# 1      3    5    422   26.4            21
# 2      3    2    408   25.5             6
# 3      0    1    403   25.2            25
# 4      5    3    383   23.9            18

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (PPG)"]
features = [" GP", " ATT", " CMP", " YDS", " YDS/G", " TD", " INT", " ATT.1", " YDS.1", " AVG", " TD.1"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [25 25 21]

# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import utils

# %%
train = pd.read_excel('Fantasy Defense Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('2020-2021 Fantasy Defense Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#     INT   SFTY   SCK   TK   FREC   FUM   DTD   PTS   PPG   PASS   RUSH  \
# 0    27      1    50  742      9    18     6   283  17.7   3854   1280
# 1    15      0    52  776     12    23     5   421  26.3   4721   2114
# 2    18      2    41  699     12    13     5   384  24.0   4106   1957
# 3    15      0    43  746     14    20     4   316  19.8   4477   1323
# 4    21      0    31  738      7    11     5   433  27.1   4141   2325
#
#     TOTAL    AVG   FPTS   FPPG  Result (Total Points)
# 0    4795  299.7    160   10.0                     84
# 1    6488  405.5    136    8.5                    115
# 2    5737  358.6    135    8.4                    124
# 3    5490  343.1    125    7.8                     87
# 4    6257  391.1    117    7.3                     69

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result (Total Points)"]
features = [" INT", " SFTY", " SCK", " TK", " FREC", " FUM", " DTD", " PTS", " PPG", " PASS", " RUSH", " TOTAL", " AVG", " FPTS", " FPPG"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [ 84  84 123 124  84 124  84 124 124 163 115 163 124  74 154 125 110  74
#  109 132  86 105  74  79 115  79  82 101 139  86  74  82]

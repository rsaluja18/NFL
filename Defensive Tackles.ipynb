# %%
import pandas as pd
import math as m
import numpy as np
import scipy as sp
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.datasets import load_iris
import random as rnd
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train = pd.read_excel('Draft Defensive Tackles Training Data.xlsx', encoding = "iso-8859-1")
test = pd.read_excel('Draft Defensive Tackles Testing Data.xlsx', encoding = "iso-8859-1")
train.head()
# Out:
#    Average Sacks  Average TFLs  Average Tackles  Average Assists  \
# 0       2.166667      9.833333        47.666667        28.666667
# 1       9.166667     21.000000        56.666667        21.000000
# 2       9.750000     18.250000        80.500000        35.000000
# 3       1.833333      9.500000        46.666667        20.333333
# 4       1.333333      3.000000        16.333333         7.333333
#
#    Average Solos  Height  Weight  BMI  Arm Length  40 Time  3 Cone Time  \
# 0      19.000000      77     328   41        0.00     5.09         8.12
# 1      35.666667      73     285   39       32.75     4.68         7.11
# 2      45.500000      76     307   38       33.50     5.03         7.21
# 3      26.333333      73     304   41       32.50     5.06         7.37
# 4       9.000000      75     327   42       33.75     5.33         7.90
#
#    20 Yard Shuttle Time  Bench Press  Result
# 0                  2.91           39      94
# 1                  4.39           35      99
# 2                  4.44           32      98
# 3                  4.56           30      92
# 4                  4.71           30      88

# %%
#X_train = train.drop("Result", axis=1)
#Y_train = train["Result"]
#X_train.shape, Y_train.shape, test.shape

y = train["Result"]
features = ["Average Sacks", "Average TFLs", "Average Tackles", "Average Assists", "Average Solos", "Height", "Weight", "BMI", "Arm Length", "40 Time", "3 Cone Time", "20 Yard Shuttle Time", "Bench Press"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

# %%
random_forest = RandomForestClassifier(n_estimators=100)

random_forest.fit(X, y)

Y_pred = random_forest.predict(X_test)
print(Y_pred)
# Out:
# [92 94 83 94]
